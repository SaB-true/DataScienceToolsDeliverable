# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# ## Author
# Santiago Brera Flores

# %% [markdown]
# ### In this notebook, Data Science Tools and Ecosystem are summarized.

# %% [markdown]
# **Objectives:**
# - Create a Jupyter Notebook
# - Practice ordered and unordered lists
# - Practice table set up
# - Popular languages and libraries
# - Practice basic arithmetic expressions in Python

# %% [markdown]
# #### Some of the popular languages that Data Scientists use are the following ones:
#
# 1. Python
# 2. R
# 3. SQL

# %% [markdown]
# #### Some of the commonly used libraries by Data Scientists include:
#
# 1. dplyr
# 2. ggplot2
# 3. TensorFlow
# 4. plotly

# %% [markdown]
# |Data Science Tools|
# |-|
# |Jupyter|
# |VS Code|
# |Spyder|
# |RStudio Server Open Source Edition|

# %% [markdown]
# ### Below are a few examples of evaluating arithmetic expressions in Python:

# %%
#This is a simple arithmetic expression to multiply then add integers.
(3*4)+5
# Out:
# 17

# %%
#This cell will convert 200 minutes to hours by dividing by 60.
200/60
# Out:
# 3.3333333333333335
